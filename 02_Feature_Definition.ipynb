# %% [markdown]
# #### Purpose of the notebook
# To restrict the Georgia BRFSS dataset to a theoretically  subset of questions relevant to the analysis of diabetes prevalence, preventive healthcare access, and socioeconomic inequality

# %% [markdown]
# ### Impor the required Libaries

# %%
# Core data handling
import pandas as pd
import numpy as np

# Reproducibility
np.random.seed(42)

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.3f}".format)

# %% [markdown]
# #### Load cleaned Gergia Dataset

# %%
# Load Georgia-only scaffold dataset
df = pd.read_csv('brfss_scaffold_clean.csv')
df.head(2)
# Out:
#    Year Locationabbr Locationdesc       Topic  \
# 0  2024           GA      Georgia  Depression
# 1  2024           GA      Georgia  Depression
#
#                                             Question Break_Out_Category  \
# 0  Ever told you that you have a form of depression?            Overall
# 1  Ever told you that you have a form of depression?            Overall
#
#   Break_Out Sample_Size  Data_value
# 0   Overall       1,297      18.500
# 1   Overall       5,923      81.600

# %%
# Key columns
df.columns
# Out:
# Index(['Year', 'Locationabbr', 'Locationdesc', 'Topic', 'Question',
#        'Break_Out_Category', 'Break_Out', 'Sample_Size', 'Data_value'],
#       dtype='object')

# %% [markdown]
# #### Identify Diabates related question

# %%
# Identify diabetes-related questions
df['Question'].unique()
# Out:
# array(['Ever told you that you have a form of depression?',
#        'What is your age?',
#        'Are you blind or do you have serious difficulty seeing, even when wearing glasses?',
#        'Ever told you have COPD?', 'Ever told you have kidney disease?',
#        'Ever told you had any other types of cancer?',
#        'Ever told you had skin cancer?',
#        'About how long has it been since you last visited a doctor for a routine checkup?',
#        'Ever told you had angina or coronary heart disease?',
#        'Ever told you had a heart attack (myocardial infarction)?',
#        'Ever told you had a stroke?', 'Adults who reported being deaf',
#        'Do you have serious difficulty concentrating, remembering, or making decisions?',
#        'Have you ever been told by a doctor that you have diabetes?',
#        'Do you have difficulty doing errands alone?',
#        'Do you have difficulty dressing or bathing?',
#        'Do you have serious difficulty walking or climbing stairs?',
#        'Adults who have had at least one drink of alcohol within the past 30 days',
#        'Do you now use e-cigarettes or other electronic vaping products every day, some days, or not at all?',
#        'What is the highest grade or year of school you completed?',
#        'What is your employment status?', 'How is your general health?',
#        'Have you ever been tested for HIV?',
#        'What is your annual household income?',
#        'What is your marital status?',
#        'Was there a time in the past 12 months when you needed to see a doctor but could not because you could not afford it?',
#        'Do you have one person (or a group of doctors) that you think of as your personal health care provider?',
#        'What is your race/ethnicity?', 'Sex of respondent',
#        'Do you currently use chewing tobacco, snuff, or snus?',
#        'Have you ever served on active duty in the United States Armed Forces?',
#        'Adults aged 65+ who have had all their natural teeth extracted (variable calculated from one or more BRFSS questions)',
#        'Weight classification by Body Mass Index (BMI) (variable calculated from one or more BRFSS questions)',
#        'Adults who have been told they currently have asthma (variable calculated from one or more BRFSS questions)',
#        'How many children live in your household? (variable calculated from one or more BRFSS questions)',
#        'Respondents aged 45-75 who have fully met the USPSTF recommendation (variable calculated from one or more BRFSS questions)',
#        'Adults who are current e-cigarette users (variable calculated from one or more BRFSS questions)',
#        'Adults who have been told they have arthritis (variable calculated from one or more BRFSS questions)',
#        'Adults that have had any permanent teeth extracted (variable calculated from one or more BRFSS questions)',
#        'Adults aged 65+ who have had a flu shot within the past year (variable calculated from one or more BRFSS questions)',
#        'Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)',
#        'Adults who had some form of health insurance (variable calculated from one or more BRFSS questions)',
#        'Calculated variable for meet USPSTF lung cancer screening guidelines',
#        'Adults who have ever been told they have asthma (variable calculated from one or more BRFSS questions)',
#        'Women aged 40-74 who have had a mammogram within the past two years (variable calculated from one or more BRFSS questions)',
#        'Days when mental health status not good (variable calculated from one or more BRFSS questions)',
#        'Respondents that have ever reported having coronary heart disease (chd) or myocardial infarction (mi) (variable calculated from one or more BRFSS questions)',
#        'Days when physical health status not good (variable calculated from one or more BRFSS questions)',
#        'Adults aged 65+ who have ever had a pneumonia vaccination (variable calculated from one or more BRFSS questions)',
#        'Binge drinkers (males having five or more drinks on one occasion, females having four or more drinks on one occasion) (variable calculated from one or more BRFSS questions)',
#        'Adults aged 45-75 who have had a blood stool test within the past year (variable calculated from one or more BRFSS questions)',
#        'Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week) (variable calculated from one or more BRFSS questions)',
#        'Health Status (variable calculated from one or more BRFSS questions)',
#        'Women aged 40+ who have had a mammogram within the past two years (variable calculated from one or more BRFSS questions)',
#        'Adults who are current smokers (variable calculated from one or more BRFSS questions)',
#        'Four Level Smoking Status (variable calculated from one or more BRFSS questions)',
#        'During the past month, did you participate in any physical activities? (variable calculated from one or more BRFSS questions)',
#        'Adults who have had their blood cholesterol checked within the last five years (variable calculated from one or more BRFSS questions)',
#        'Adults who are current e-cigarette users (variable calculated from one or more BRFSS questions',
#        'Respondents who have reported having driven after drinking too much (variable calculated from one or more BRFSS questions)',
#        'Participated in 150 minutes or more of Aerobic Physical Activity per week (variable calculated from one or more BRFSS questions)',
#        'Participated in enough Aerobic and Muscle Strengthening exercises to meet guidelines (variable calculated from one or more BRFSS questions)',
#        'Participated in muscle strengthening exercises two or more times per week (variable calculated from one or more BRFSS questions)',
#        'Adults who have had their blood cholesterol checked and have been told it was high (variable calculated from one or more BRFSS questions)',
#        'Adults who have been told they have high blood pressure (variable calculated from one or more BRFSS questions)',
#        'Always or nearly always wears a seat belt?',
#        'Visited the dentist or dental clinic within the past year for any reason (variable calculated from one or more BRFSS questions)',
#        'Respondents aged 50-80 who are current and former smokers who had CAT/CT scan in last year',
#        'Women aged 50-74 who have had a mammogram within the past two years (variable calculated from one or more BRFSS questions)',
#        'Do you own or rent your home?',
#        'Consumed fruit less than one time per day (variable calculated from one or more BRFSS questions)',
#        'Are you now limited in any way in any of your usual activities because of arthritis? (variable calculated from one or more BRFSS questions)',
#        'Do arthritis or joint symptoms now affect whether you work? (variable calculated from one or more BRFSS questions)',
#        'Consumed vegetables less than one time per day (variable calculated from one or more BRFSS questions)',
#        'Adults aged 50-75 who have had a blood stool test within the past year (variable calculated from one or more BRFSS questions)',
#        'Respondents aged 50-75 who have fully met the USPSTF recommendation (variable calculated from one or more BRFSS questions)',
#        'Men aged 40+ who have had a PSA test within the past two years (variable calculated from one or more BRFSS questions)',
#        'Do you have one person you think of as your personal doctor or health care provider?',
#        'Do you have any kind of health care coverage?',
#        'Was there a time in the past 12 months when you needed to see a doctor but could not because of cost?',
#        'Women aged 21-65 who have had a pap test in the past three years (variable calculated from one or more BRFSS questions)',
#        'Since 2005, have you had a tetanus shot?',
#        'Aged 50-75 had a blood stool test within the past 3 years',
#        'Aged 50-75 had a colonoscopy in the past 10 years',
#        'Aged 50-75 had a sigmoidoscopy within the past 5 years',
#        'Does arthritis or joint symptoms interfere with your normal social activities? (variable calculated from one or more BRFSS questions)',
#        'Have you ever had the shingles or zoster vaccine?',
#        'E-cigarette use status', 'Current E-cigarette user',
#        'Have you used the internet in the past 30 days?',
#        'Adults who are limited in any activities because of physical, mental, or emotional problems',
#        'Adults with health problem(s) that requires the use of special equipment',
#        'Adults who have ever had their blood cholesterol checked',
#        'Participated in muscle strengthening exercises two or more times per week (variable calculated from one or more BRFSS questions).',
#        'Always wears a seat belt? (variable calculated from one or more BRFSS questions)',
#        'Heavy drinkers (adult men having more than two drinks per day and adult women having more than one drink per day) (variable calculated from one or more BRFSS questions)',
#        'Women aged 50+ who have had a mammogram within the past two years (variable calculated from one or more BRFSS questions)',
#        'Women aged 18+ who have had a pap test within the past three years (variable calculated from one or more BRFSS questions)',
#        'Adults aged 50+ who have had a blood stool test within the past two years (variable calculated from one or more BRFSS questions)',
#        'Adults aged 50+ who have ever had a sigmoidoscopy or colonoscopy (variable calculated from one or more BRFSS questions)',
#        'Ever told you have vision impairment?'], dtype=object)

# %% [markdown]
# #### Define the Relevant questions

# %% [markdown]
# - Outcome variable (Diabetes)

# %%
diabetes_question = [
    "Have you ever been told by a doctor that you have diabetes?"
]

# %% [markdown]
# - Preventive Healthcare Access (Treatment Variables)

# %%
#Preventive questions
prevention_questions = [
    "About how long has it been since you last visited a doctor for a routine checkup?",
    "Do you have any kind of health care coverage?",
    "Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)"
]

# %% [markdown]
# - Socioeconomic Status (Inequality Stratifiers)

# %%
# Social Economic questions
ses_questions = [
    "What is your annual household income?",
    "What is the highest grade or year of school you completed?",
    "What is your race/ethnicity?",
    "Sex of respondent"
]

# %% [markdown]
# - Risk Factors for Machine Learning and Interpretation

# %%
#Risk Factor questions
risk_factor_questions = [
    "Weight classification by Body Mass Index (BMI) (variable calculated from one or more BRFSS questions)",
    "Adults who are current smokers (variable calculated from one or more BRFSS questions)",
    "During the past month, did you participate in any physical activities? (variable calculated from one or more BRFSS questions)",
    "Adults who have been told they have high blood pressure (variable calculated from one or more BRFSS questions)",
    "Adults who have had their blood cholesterol checked and have been told it was high (variable calculated from one or more BRFSS questions)"
]

# %% [markdown]
# #### Creating Individual data frames

# %%
# Outcome Group (Diabetes)
df_diabetes = df[df['Question'].isin(diabetes_question)].copy()
df_diabetes["Question_Role"] = "Outcome (Diabetes)"

#  Prevention Group (Healthcare Access)
df_prevention = df[df["Question"].isin(prevention_questions)].copy()
df_prevention["Question_Role"] = "Prevention (Treatment)"

# Socioeconomic Status (SES)
df_ses = df[df["Question"].isin(ses_questions)].copy()
df_ses["Question_Role"] = "Socioeconomic Status"

# Risk Factors (for ML)
df_risk = df[df["Question"].isin(risk_factor_questions)].copy()
df_risk["Question_Role"] = "Risk Factor"

# %% [markdown]
# #### Merging the data frames

# %%
# Combine all individual dataframes into one master analysis set
df_relevant = pd.concat([df_diabetes, df_prevention, df_ses, df_risk], ignore_index=True)

# Important: Convert data values to numbers now while they are in one place
df_relevant["Data_value"] = pd.to_numeric(df_relevant["Data_value"], errors='coerce')

# Drop rows that don't have a numerical value (cannot be used for analysis)
df_relevant = df_relevant.dropna(subset=["Data_value"])

print(f"Dataset successfully merged. Total usable rows: {df_relevant.shape[0]:,}")
# Out:
# Dataset successfully merged. Total usable rows: 19,594

# %% [markdown]
# #### Verify the groups

# %%
# Check that all roles exist and have data
role_check = df_relevant.groupby("Question_Role").agg(
    Record_Count=('Data_value', 'count'),
    Average_Value=('Data_value', 'mean')
).round(2)

display(role_check)
# Out:
#                         Record_Count  Average_Value
# Question_Role
# Outcome (Diabetes)              1605         40.270
# Prevention (Treatment)          4020         40.310
# Risk Factor                     6069         43.480
# Socioeconomic Status            7900         26.860

# %% [markdown]
# #### Check the distrivution of newly assigned roles

# %%
# Check the distribution of your newly assigned roles
print(df_relevant["Question_Role"].value_counts())
# Out:
# Question_Role
# Socioeconomic Status      7900
# Risk Factor               6069
# Prevention (Treatment)    4020
# Outcome (Diabetes)        1605
# Name: count, dtype: int64

# %% [markdown]
# #### Validation

# %%
# Run this to see the exact strings used in the dataset
print(df_relevant['Question'].unique()[:20])
# Out:
# ['Have you ever been told by a doctor that you have diabetes?'
#  'About how long has it been since you last visited a doctor for a routine checkup?'
#  'Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)'
#  'Do you have any kind of health care coverage?'
#  'What is the highest grade or year of school you completed?'
#  'What is your annual household income?' 'What is your race/ethnicity?'
#  'Sex of respondent'
#  'Weight classification by Body Mass Index (BMI) (variable calculated from one or more BRFSS questions)'
#  'Adults who are current smokers (variable calculated from one or more BRFSS questions)'
#  'During the past month, did you participate in any physical activities? (variable calculated from one or more BRFSS questions)'
#  'Adults who have had their blood cholesterol checked and have been told it was high (variable calculated from one or more BRFSS questions)'
#  'Adults who have been told they have high blood pressure (variable calculated from one or more BRFSS questions)']

# %%
# Check how many rows were found for each specific category
# This ensures no question was "lost" due to a typo
question_counts = df_relevant['Question'].value_counts()

print(f"Total rows extracted: {df_relevant.shape[0]:,}")
print("\nRows found per question:")
print(question_counts)
# Out:
# Total rows extracted: 19,594
#
# Rows found per question:
# Question
# What is your annual household income?                                                                                                        2425
# What is your race/ethnicity?                                                                                                                 2202
# Weight classification by Body Mass Index (BMI) (variable calculated from one or more BRFSS questions)                                        2167
# What is the highest grade or year of school you completed?                                                                                   2034
# About how long has it been since you last visited a doctor for a routine checkup?                                                            1941
# Have you ever been told by a doctor that you have diabetes?                                                                                  1605
# During the past month, did you participate in any physical activities? (variable calculated from one or more BRFSS questions)                1320
# Adults who are current smokers (variable calculated from one or more BRFSS questions)                                                        1274
# Sex of respondent                                                                                                                            1239
# Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)                           1185
# Do you have any kind of health care coverage?                                                                                                 894
# Adults who have been told they have high blood pressure (variable calculated from one or more BRFSS questions)                                657
# Adults who have had their blood cholesterol checked and have been told it was high (variable calculated from one or more BRFSS questions)     651
# Name: count, dtype: int64

# %% [markdown]
# #### Renaming the Variable Names

# %%
# Mapping Dictionary: Long Question -> Short Variable Name
rename_map = {
    # Outcome
    "Have you ever been told by a doctor that you have diabetes?": "diabetes_status",
    
    # Preventive Healthcare
    "About how long has it been since you last visited a doctor for a routine checkup?": "last_checkup",
    "Do you have any kind of health care coverage?": "health_insurance",
    "Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)": "insurance_18_64",
    
    # Socioeconomic Status
    "What is your annual household income?": "income_level",
    "What is the highest grade or year of school you completed?": "education_level",
    "What is your race/ethnicity?": "race_ethnicity",
    "Sex of respondent": "gender",
    
    # Risk Factors
    "Weight classification by Body Mass Index (BMI) (variable calculated from one or more BRFSS questions)": "bmi_category",
    "Adults who are current smokers (variable calculated from one or more BRFSS questions)": "smoking_status",
    "During the past month, did you participate in any physical activities? (variable calculated from one or more BRFSS questions)": "physical_activity",
    "Adults who have been told they have high blood pressure (variable calculated from one or more BRFSS questions)": "high_blood_pressure",
    "Adults who have had their blood cholesterol checked and have been told it was high (variable calculated from one or more BRFSS questions)": "high_cholesterol"
}

# Apply the mapping to a new column
df_relevant["Variable_Name"] = df_relevant["Question"].map(rename_map)

# %%
df_relevant.head(3)
# Out:
#    Year Locationabbr Locationdesc     Topic  \
# 0  2024           GA      Georgia  Diabetes
# 1  2024           GA      Georgia  Diabetes
# 2  2024           GA      Georgia  Diabetes
#
#                                             Question Break_Out_Category  \
# 0  Have you ever been told by a doctor that you h...            Overall
# 1  Have you ever been told by a doctor that you h...            Overall
# 2  Have you ever been told by a doctor that you h...            Overall
#
#   Break_Out Sample_Size  Data_value       Question_Role    Variable_Name
# 0   Overall       1,242      12.800  Outcome (Diabetes)  diabetes_status
# 1   Overall          46       0.600  Outcome (Diabetes)  diabetes_status
# 2   Overall       5,779      84.100  Outcome (Diabetes)  diabetes_status

# %% [markdown]
# #### Verifying the New schema

# %%
# Create a clean lookup table of your new variable names
schema_check = df_relevant[["Question_Role", "Variable_Name", "Question"]].drop_duplicates()
display(schema_check)
# Out:
#                 Question_Role        Variable_Name  \
# 0          Outcome (Diabetes)      diabetes_status
# 1605   Prevention (Treatment)         last_checkup
# 1699   Prevention (Treatment)      insurance_18_64
# 2663   Prevention (Treatment)     health_insurance
# 5625     Socioeconomic Status      education_level
# 5708     Socioeconomic Status         income_level
# 5824     Socioeconomic Status       race_ethnicity
# 5913     Socioeconomic Status               gender
# 13525             Risk Factor         bmi_category
# 13613             Risk Factor       smoking_status
# 13664             Risk Factor    physical_activity
# 13935             Risk Factor     high_cholesterol
# 13987             Risk Factor  high_blood_pressure
#
#                                                 Question
# 0      Have you ever been told by a doctor that you h...
# 1605   About how long has it been since you last visi...
# 1699   Adults aged 18-64 who have any kind of health ...
# 2663       Do you have any kind of health care coverage?
# 5625   What is the highest grade or year of school yo...
# 5708               What is your annual household income?
# 5824                        What is your race/ethnicity?
# 5913                                   Sex of respondent
# 13525  Weight classification by Body Mass Index (BMI)...
# 13613  Adults who are current smokers (variable calcu...
# 13664  During the past month, did you participate in ...
# 13935  Adults who have had their blood cholesterol ch...
# 13987  Adults who have been told they have high blood...

# %% [markdown]
# #### Final Numeric check

# %%
df_relevant["Data_value"] = pd.to_numeric(df_relevant["Data_value"], errors='coerce')
df_relevant = df_relevant.dropna(subset=["Data_value"])
df_relevant.shape
# Out:
# (19594, 11)

# %%
# Validation: Check if the filter returned rows
if diabetes_df.empty:
    print("Warning: No records found for the specified diabetes question. Check for exact string matches.")
else:
    print(f"Successfully isolated {len(diabetes_df):,} records for diabetes analysis.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Validation: Check if the filter returned rows
# ----> 2 if diabetes_df.empty:
#       3     print("Warning: No records found for the specified diabetes question. Check for exact string matches.")
#       4 else:
#
# NameError: name 'diabetes_df' is not defined

# %%
# Inspect the response categories for the selected question
print("Available response categories:")
print(diabetes_df['Break_Out'].unique())

# %%
# Grouping prevention and access questions for thematic analysis
prevention_questions = [
    "About how long has it been since you last visited a doctor for a routine checkup?",
    "Do you have any kind of health care coverage?",
    "Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)"
]

# Filtering the dataset
prevention_df =df[df['Question'].isin(prevention_questions)].copy()

# %%
# Create a mapping for cleaner visualizations later
question_map = {
    "About how long has it been since you last visited a doctor for a routine checkup?": "Last_Checkup",
    "Do you have any kind of health care coverage?": "Has_Coverage_Raw",
    "Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)": "Has_Coverage_Calculated"
}

# Apply a short-name column if pivoting the data later
prevention_df['Question_Short'] = prevention_df['Question'].map(question_map)

# %%
# Create a clean label for every question in your relevant list
clean_label_map = {
    # Outcome
    "Have you ever been told by a doctor that you have diabetes?": "diabetes_status",
    
    # Risk Factors
    "Weight classification by Body Mass Index (BMI) (variable calculated from one or more BRFSS questions)": "bmi_category",
    "Adults who are current smokers (variable calculated from one or more BRFSS questions)": "smoking_status",
    "Adults who have been told they have high blood pressure (variable calculated from one or more BRFSS questions)": "high_bp",
    
    # SES / Prevention
    "What is your annual household income?": "income_level",
    "Do you have any kind of health care coverage?": "healthcare_access",
    "During the past month, did you participate in any physical activities? (variable calculated from one or more BRFSS questions)": "physical_activity"
}

# Apply the clean labels to a new column
df_relevant["Clean_Question"] = df_relevant["Question"].map(clean_label_map).fillna("other_metric")

# %% [markdown]
# #### Save the dataset for Analysis

# %%
#Save as CSV 
df_relevant.to_csv("brfss_diabetes_cleaned.csv", index=False)

print("Success! Dataset saved for the next session.")
# Out:
# Success! Dataset saved for the next session.
